# %%
import pandas as pd

# %%
data1 = '/Users/kimdong-keon/Desktop/projects/dbfiles/1.credits.csv'
data2 = '/Users/kimdong-keon/Desktop/projects/dbfiles/keywords_cleaned.csv' 
data3 = '/Users/kimdong-keon/Desktop/projects/dbfiles/links_cleaned.csv' 
data4 = '/Users/kimdong-keon/Desktop/projects/dbfiles/ratings_cleaned.csv'
# metadata_cleaned 는 5번째
data5 = '/Users/kimdong-keon/Desktop/projects/dbfiles/movies_metadata_cleaned.csv' 

pd.read_csv(data1)
# Out:
#        Unnamed: 0                                               cast  \
# 0               0  Tom Hanks,Tim Allen,Don Rickles,Jim Varney,Wal...
# 1               1  Robin Williams,Jonathan Hyde,Kirsten Dunst,Bra...
# 2               2  Walter Matthau,Jack Lemmon,Ann-Margret,Sophia ...
# 3               3  Whitney Houston,Angela Bassett,Loretta Devine,...
# 4               4  Steve Martin,Diane Keaton,Martin Short,Kimberl...
# ...           ...                                                ...
# 45499       45499                                                NaN
# 45500       45500                                                NaN
# 45501       45501                                                NaN
# 45502       45502                                                NaN
# 45503       45503                                                NaN
#
#                                                     crew      id
# 0      John Lasseter,Joss Whedon,Andrew Stanton,Joel ...     862
# ...

# %%
df_1 = df_1[['cast', 'crew', 'id']]
df_1.head()
df_1.to_csv('/Users/kimdong-keon/Desktop/projects/dbfiles/1.credits.csv')

# %%
df_1
# Out:
#                                                     cast  \
# 0      Tom Hanks,Tim Allen,Don Rickles,Jim Varney,Wal...
# 1      Robin Williams,Jonathan Hyde,Kirsten Dunst,Bra...
# 2      Walter Matthau,Jack Lemmon,Ann-Margret,Sophia ...
# 3      Whitney Houston,Angela Bassett,Loretta Devine,...
# 4      Steve Martin,Diane Keaton,Martin Short,Kimberl...
# ...                                                  ...
# 45499                                                NaN
# 45500                                                NaN
# 45501                                                NaN
# 45502                                                NaN
# 45503                                                NaN
#
#                                                     crew      id
# 0      John Lasseter,Joss Whedon,Andrew Stanton,Joel ...     862
# 1      Larry J. Franco,Jonathan Hensleigh,James Horne...    8844
# 2      Howard Deutch,Mark Steven Johnson,Mark Steven ...   15602
# ...

# %%
df_1.loc[40000]['cast']
# Out:
# nan

# %%
df_2 = pd.read_csv('/Users/kimdong-keon/Desktop/projects/dbfiles/keywords_cleaned.csv', encoding='mac_roman')
df_2.to_csv('/Users/kimdong-keon/Desktop/projects/dbfiles/2.keywords.csv')
df_2
# Out:
#            id                                           keywords  \
# 0         862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1        8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2       15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3       31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4       11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# ...       ...                                                ...
# 46414  439050             [{'id': 10703, 'name': 'tragic love'}]
# 46415  111109  [{'id': 2679, 'name': 'artist'}, {'id': 14531,...
# 46416   67758                                                 []
# 46417  227506                                                 []
# 46418  461257                                                 []
#
#                                               keywords.1
# 0      jealousy,toy,boy,friendship,friends,rivalry,bo...
# 1      board game,disappearance,new home,recluse,gian...
# ...

# %%
df_3 = pd.read_csv(data3)
df_3.to_csv('/Users/kimdong-keon/Desktop/projects/dbfiles/3.links.csv')

# %%
df_3
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45619   176269  6209470  439050.0
# 45620   176271  2028550  111109.0
# 45621   176273   303758   67758.0
# 45622   176275     8536  227506.0
# 45623   176279  6980792  461257.0
#
# [45624 rows x 3 columns]

# %%
df_4 = pd.read_csv(data4, encoding='mac_roman')
df_4
df_4.to_csv('/Users/kimdong-keon/Desktop/projects/dbfiles/4.ratings.csv')

# %%
df_5 = pd.read_csv(data5, encoding='mac_roman')
df_5
# Out:
#        adult           belongs_to_collection                    genres  \
# 0      FALSE            Toy Story Collection   Animation,Comedy,Family
# 1      FALSE                                  Adventure,Fantasy,Family
# 2      FALSE       Grumpy Old Men Collection            Romance,Comedy
# 3      FALSE                                      Comedy,Drama,Romance
# 4      FALSE  Father of the Bride Collection                    Comedy
# ...      ...                             ...                       ...
# 45450  FALSE                                              Drama,Family
# 45451  FALSE                                                     Drama
# 45452  FALSE                                     Action,Drama,Thriller
# 45453  FALSE                                                       NaN
# 45454  FALSE                                                       NaN
#
#            id  imdb_id original_language               original_title  \
# ...

# %%
pd.read_csv(data5)
# Out:
#          userId  movieId  rating
# 0             1      110     1.0
# 1             1      147     4.5
# 2             1      858     5.0
# 3             1     1221     5.0
# 4             1     1246     5.0
# ...         ...      ...     ...
# 1048570   10656     1608     2.0
# 1048571   10656     1610     3.0
# 1048572   10656     1614     3.0
# 1048573   10656     1616     1.0
# 1048574   10656     1617     4.0
#
# [1048575 rows x 3 columns]
